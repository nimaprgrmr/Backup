# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tarikhche_data = pd.read_csv("tarikhche kharid.csv")

# %%
tarikhche_data.head()
# Out:
#          id  product_variant_id  selling_price  rrp_price base_price  \
# 0  18752043             1977385         850000     850000         \N
# 1  18752022             1977380       12550000   12550000         \N
# 2  18752046             1977380       12500000   12500000         \N
# 3  18751982             1977374         310000     310000         \N
# 4  18752018             1977374         300000     300000         \N
#
#   buy_price  order_limit start_at end_at tags  show_in_price_history  active  \
# 0        \N            1       \N     \N   \N                      1       1
# 1        \N            2       \N     \N   \N                      1       0
# 2        \N            2       \N     \N   \N                      1       1
# 3        \N            2       \N     \N   \N                      1       0
# 4        \N            2       \N     \N   \N                      1       1
#
#             created_at  product_id  marketplace_seller_id
# ...

# %%
tarikhche_data.groupby("id").sum()
# Out:
# C:\Users\Nima\AppData\Local\Temp\ipykernel_1512\1608459731.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tarikhche_data.groupby("id").sum()
#           product_variant_id  selling_price  rrp_price  order_limit  \
# id
# 7003798              1155042         500000     500000            1
# 7003805              1155042         529000     529000            1
# 7003853              1155053         300000     300000            1
# 7003861              1155053         309000     309000            1
# 7003922              1155066         125000     125000           10
# ...                      ...            ...        ...          ...
# 18752066             1897273        3700000    3700000            5
# 18752067             1318900         202000     202000           10
# ...
