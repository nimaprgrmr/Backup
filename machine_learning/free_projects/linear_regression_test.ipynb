# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('Ecommerce_Customers.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
data.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
data.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
data.columns = ['email', 'address', 'avatar', 'avg_session_lenght', 'time_on_app', 'time_on_website', 'length_of_membership', 'yearly_amount_spent']

# %%
data.head()
# Out:
#                            email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              address            avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    avg_session_lenght  time_on_app  time_on_website  length_of_membership  \
# 0           34.497268    12.655651        39.577668              4.082621
# 1           31.926272    11.109461        37.268959              2.664034
# 2           33.000915    11.330278        37.110597              4.104543
# ...

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='time_on_app', y='yearly_amount_spent', data=data)
# Out:
# <AxesSubplot:xlabel='time_on_app', ylabel='yearly_amount_spent'>

# %%
plt.figure(figsize=(10,7))
plt.bar(x='time_on_app', data=data, height='yearly_amount_spent', edgecolor='k',linewidth=2)
# Out:
# <BarContainer object of 500 artists>

# %%
sns.jointplot(x='time_on_app', y='yearly_amount_spent', data=data)

# %%
sns.jointplot(x='time_on_website', y='yearly_amount_spent', data=data)

# %%
data = data.drop(['email', 'address', 'avatar'], axis=1)

# %%
data.head()
# Out:
#    avg_session_lenght  time_on_app  time_on_website  length_of_membership  \
# 0           34.497268    12.655651        39.577668              4.082621
# 1           31.926272    11.109461        37.268959              2.664034
# 2           33.000915    11.330278        37.110597              4.104543
# 3           34.305557    13.717514        36.721283              3.120179
# 4           33.330673    12.795189        37.536653              4.446308
#
#    yearly_amount_spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
sns.lmplot(data=data, x='time_on_app', y='yearly_amount_spent')

# %%
sns.lmplot(data=data, x='avg_session_lenght', y='yearly_amount_spent')

# %%
sns.lmplot(data=data, x='time_on_website', y='yearly_amount_spent')

# %%
sns.lmplot(data=data, x='length_of_membership', y='yearly_amount_spent')

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
X=data.drop('yearly_amount_spent', axis=1)

# %%
y = data['yearly_amount_spent']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(x=y_test, y=predictions)

# %%
data.head()
# Out:
#    avg_session_lenght  time_on_app  time_on_website  length_of_membership  \
# 0           34.497268    12.655651        39.577668              4.082621
# 1           31.926272    11.109461        37.268959              2.664034
# 2           33.000915    11.330278        37.110597              4.104543
# 3           34.305557    13.717514        36.721283              3.120179
# 4           33.330673    12.795189        37.536653              4.446308
#
#    yearly_amount_spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
new_row = {'avg_session_lenght':50, 'time_on_app':13, 'time_on_website':37, 'length_of_membership':5.922689}

# %%
df2 = data.append(new_row, ignore_index=True)

# %%
df2
# Out:
#      avg_session_lenght  time_on_app  time_on_website  length_of_membership  \
# 0             34.497268    12.655651        39.577668              4.082621
# 1             31.926272    11.109461        37.268959              2.664034
# 2             33.000915    11.330278        37.110597              4.104543
# 3             34.305557    13.717514        36.721283              3.120179
# 4             33.330673    12.795189        37.536653              4.446308
# ..                  ...          ...              ...                   ...
# 496           34.702529    11.695736        37.190268              3.576526
# 497           32.646777    11.499409        38.332576              4.958264
# 498           33.322501    12.391423        36.840086              2.336485
# 499           33.715981    12.418808        35.771016              2.735160
# 500           50.000000    13.000000        37.000000              5.922689
#
#      yearly_amount_spent
# 0             587.951054
# ...

# %%
lm.predict(df2[500])

# %%
data.loc[[4],['yearly_amount_spent']]
# Out:
#    yearly_amount_spent
# 4           599.406092

# %%
df2.loc[[500]]
# Out:
#      avg_session_lenght  time_on_app  time_on_website  length_of_membership  \
# 500                50.0         13.0             37.0              5.922689
#
#      yearly_amount_spent
# 500                  NaN

# %%
X1 = df2.drop('yearly_amount_spent', axis=1)

# %%
y1=df2['yearly_amount_spent']

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.33,random_state=1)

# %%
sample = df2.loc[[500]].drop('yearly_amount_spent', axis=1)

# %%
prediction = lm.predict(sample)

# %%
prediction
# Out:
# array([1121.16633432])

# %%
sample = df2.loc[[500]]
