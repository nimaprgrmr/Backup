# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# %matplotlib inline

# %%
data_of_ad = pd.read_csv("advertising.csv")
data_of_ad.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
# beyne kalame haye col data set ma space ast anra edit mikonim

# %%
data_of_ad.columns = ['daily_time_spent_on_site', 'age', 'area_income','daily_internet_usage',
                     'ad_topic_line', 'city', 'male', 'country', 'timestamp', 'clicked_on_ad']

# %%
data_of_ad.head()
# Out:
#    daily_time_spent_on_site  age  area_income  daily_internet_usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            ad_topic_line            city  male     country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              timestamp  clicked_on_ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
data_of_ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   daily_time_spent_on_site  1000 non-null   float64
#  1   age                       1000 non-null   int64
#  2   area_income               1000 non-null   float64
#  3   daily_internet_usage      1000 non-null   float64
#  4   ad_topic_line             1000 non-null   object
#  5   city                      1000 non-null   object
#  6   male                      1000 non-null   int64
#  7   country                   1000 non-null   object
#  8   timestamp                 1000 non-null   object
#  9   clicked_on_ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
data_of_ad.describe()
# Out:
#        daily_time_spent_on_site          age   area_income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        daily_internet_usage         male  clicked_on_ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %%
data_of_ad['age'].plot.hist(bins=30);
# plt.hist(x= data_of_ad['age'], bins=30);

# %%
sns.jointplot(x='age', y='area_income', data=data_of_ad);

# %%
sns.jointplot(x='age', y='daily_time_spent_on_site', data=data_of_ad, kind='kde')

# %%
sns.jointplot(x='daily_time_spent_on_site', y='daily_internet_usage', data=data_of_ad)

# %%
sns.pairplot(data=data_of_ad, hue='clicked_on_ad');

# %%
sns.heatmap(data_of_ad.isnull(),yticklabels=False, cbar=False);
#neshan midahad ke hich miss datayi nadarim

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
data_of_ad.head()
# Out:
#    daily_time_spent_on_site  age  area_income  daily_internet_usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            ad_topic_line            city  male     country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              timestamp  clicked_on_ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
X = data_of_ad.drop(['ad_topic_line', 'city', 'country', 'timestamp', 'clicked_on_ad'], axis=1)

# %%
y = data_of_ad['clicked_on_ad']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
log_model = LogisticRegression()

# %%
log_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
predictions = log_model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       157
#            1       0.94      0.90      0.92       143
#
#     accuracy                           0.93       300
#    macro avg       0.93      0.93      0.93       300
# weighted avg       0.93      0.93      0.93       300

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[149   8]
#  [ 14 129]]

# %%
# ba maghadire awlie mohasebeye model kar ra tamam mikonim ;)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
pred_rfc = rfc.predict(X_test)

# %%
print(classification_report(y_test, pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       157
#            1       0.96      0.94      0.95       143
#
#     accuracy                           0.96       300
#    macro avg       0.96      0.96      0.96       300
# weighted avg       0.96      0.96      0.96       300

# %%
# in taghirat bad az yad grftane random forest boode ast, mibnim ke algorithm random forest pishbini behtari karde ast.
